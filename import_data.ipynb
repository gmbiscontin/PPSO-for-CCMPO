# %%
import pandas as pd
# import with the name of the columns
data=pd.read_csv('stoxx600_data.csv', sep=',', header=0)
data1=data.iloc[:,1:21]
data1
# Out:
#       3I GROUP  A P MOLLER MAERSK B     A2A     AAK  AALBERTS  ABB LTD N  \
# 0        704.0              9825.19  1.2300   99.92    30.820      21.48
# 1        704.0             10165.19  1.2620  101.08    31.130      21.48
# 2        712.0             10252.37  1.2610   99.75    31.005      21.73
# 3        717.0             10121.60  1.2690  100.17    30.965      21.76
# 4        722.5             10391.85  1.2650   99.92    31.035      21.77
# ...        ...                  ...     ...     ...       ...        ...
# 1343    1313.0             21890.00  1.5360  174.70    51.860      30.65
# 1344    1245.5             20900.00  1.5045  172.00    49.140      29.96
# 1345    1307.0             21490.00  1.5740  173.75    50.860      30.92
# 1346    1335.5             21020.00  1.5970  172.95    49.710      31.15
# 1347    1296.0             20630.00  1.5415  169.65    46.950      30.59
#
#       ABN AMRO BANK   ABRDN   ACCIO   ACCOR  ACKERMANS & VAN HAAREN  \
# ...

# %%
# drop the column with the na
data1.dropna(axis=1, how='any', inplace=True)
data1.shape
# Out:
# (1348, 18)

# %%
# dave data1 as csv
data1.to_csv('stoxx10.csv', sep=';', header=None, index=False)

# %%
# convert all the columns to numeric
data1=data1.apply(pd.to_numeric)

# %%
# calcuala il rendimento in percetuale per ogni azione
data2= data1.pct_change()
data2
# Out:
#             0         1         2         3         4         5         6   \
# 0          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1     0.042569 -0.003669  0.067142  0.051110  0.004492  0.027007  0.011913
# 2     0.019341  0.010315  0.020413  0.027608  0.001910 -0.001957  0.012909
# 3    -0.002811  0.002185  0.001645  0.026866 -0.026743  0.024399  0.005771
# 4    -0.023961 -0.014548 -0.014148  0.005691 -0.013745 -0.004764  0.007491
# ...        ...       ...       ...       ...       ...       ...       ...
# 1392 -0.028474  0.004399 -0.029496 -0.017472 -0.197861 -0.007634  0.061776
# 1393 -0.005275  0.001946 -0.011119 -0.001569 -0.003333 -0.007692 -0.022545
# 1394 -0.010018  0.006314 -0.005247 -0.003143 -0.016722  0.023256  0.003720
# 1395  0.002976  0.004826 -0.030143 -0.011035 -0.037415  0.000000 -0.028910
# 1396  0.007122 -0.004803 -0.005439  0.022848  0.085512  0.038636  0.008397
#
# ...

# %%
data2
# Out:
#             0         1         2         3         4         5         6   \
# 0          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1     0.042569 -0.003669  0.067142  0.051110  0.004492  0.027007  0.011913
# 2     0.019341  0.010315  0.020413  0.027608  0.001910 -0.001957  0.012909
# 3    -0.002811  0.002185  0.001645  0.026866 -0.026743  0.024399  0.005771
# 4    -0.023961 -0.014548 -0.014148  0.005691 -0.013745 -0.004764  0.007491
# ...        ...       ...       ...       ...       ...       ...       ...
# 1392 -0.028474  0.004399 -0.029496 -0.017472 -0.197861 -0.007634  0.061776
# 1393 -0.005275  0.001946 -0.011119 -0.001569 -0.003333 -0.007692 -0.022545
# 1394 -0.010018  0.006314 -0.005247 -0.003143 -0.016722  0.023256  0.003720
# 1395  0.002976  0.004826 -0.030143 -0.011035 -0.037415  0.000000 -0.028910
# 1396  0.007122 -0.004803 -0.005439  0.022848  0.085512  0.038636  0.008397
#
# ...

# %%
# 'Asset_1', 'Asset_2', 'Asset_3', 'Asset_4', 'Asset_5', 'Asset_6', 'Asset_7', 'Asset_8', 'Asset_9', 'Asset_10'
